# %% [markdown]
# Opdracht 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Opdracht 2.1
dataset = pd.read_csv('student_performance_basis.csv')

# Opdracht 2.2
dataset
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Opdracht 2.1
# ----> 2 dataset = pd.read_csv('student_performance_basis.csv')
#       4 # Opdracht 2.2
#       5 dataset
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# Opdracht 2.3
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1044 non-null   int64
#  1   sex       1044 non-null   object
#  2   Medu      1044 non-null   int64
#  3   Fedu      1044 non-null   int64
#  4   reason    1044 non-null   object
#  5   absences  1044 non-null   int64
#  6   G1        1044 non-null   int64
#  7   G3        1044 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 65.4+ KB

# %%
# Opdracht 2.4
dataset.dtypes
# Out:
# age          int64
# sex         object
# Medu         int64
# Fedu         int64
# reason      object
# absences     int64
# G1           int64
# G3           int64
# dtype: object

# %% [markdown]
# | Variabele  | Omschrijving                                        | Datatype   | Numeriek/categorisch | Soort variabele | Mogelijke waarden                                      |
# |------------|-----------------------------------------------------|------------|----------------------|-----------------|--------------------------------------------------------|
# | sex        | Geslacht van de student                             | String     | Categorisch          | Nominaal        | "F" (vrouwelijk) of "M" (mannelijk)                     |
# | age        | Leeftijd van de student                             | Integer    | Numeriek              | Ratio           | 15 tot 22                                               |
# | Medu       | Opleidingsniveau van de moeder                      | Integer    | Ordinaal              | Ordinaal        | 0 (geen), 1 (primair), 2 (5e tot 9e klas), 3 (secundair), 4 (hoger) |
# | Fedu       | Opleidingsniveau van de vader                       | Integer    | Ordinaal              | Ordinaal        | 0 (geen), 1 (primair), 2 (5e tot 9e klas), 3 (secundair), 4 (hoger) |
# | reason     | Reden om voor deze school te kiezen                | String     | Categorisch          | Nominaal        | "home", "reputation", "course", "other"                |
# | absences   | Aantal schoolverzuimen                             | Integer    | Numeriek              | Ratio           | 0 tot 93                                                |
# | G1         | Cijfer voor het eerste lesperiode                   | Integer    | Numeriek              | Ratio           | 0 tot 20                                                |
# | G3         | Eindcijfer (doelvariabele)                         | Integer    | Numeriek              | Ratio           | 0 tot 20                                                |

# %% [markdown]
# Opdracht 3

# %%
# Hieronder wordt er onderscheid gemaakt in categorische en numerieke variabelen
cat_vars = ["sex", "reason", "Medu", "Fedu"]
num_vars = ["age", "absences", "G1", "G3"]

# %%
# Opdracht 3.1a
dataset["sex"].value_counts()
# Out:
# sex
# F    591
# M    453
# Name: count, dtype: int64

# %%
dataset["reason"].value_counts()
# Out:
# reason
# course        430
# home          258
# reputation    248
# other         108
# Name: count, dtype: int64

# %%
dataset["Medu"].value_counts()
# Out:
# Medu
# 4    306
# 2    289
# 3    238
# 1    202
# 0      9
# Name: count, dtype: int64

# %%
dataset["Fedu"].value_counts()
# Out:
# Fedu
# 2    324
# 1    256
# 3    231
# 4    224
# 0      9
# Name: count, dtype: int64

# %%
# Opdracht 3.1b
sns.countplot(dataset, x = "sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(dataset, x = "reason")
# Out:
# <Axes: xlabel='reason', ylabel='count'>

# %%
sns.countplot(dataset, x = "Medu")
# Out:
# <Axes: xlabel='Medu', ylabel='count'>

# %%
sns.countplot(dataset, x = "Fedu")
# Out:
# <Axes: xlabel='Fedu', ylabel='count'>

# %%
# Opdracht 3.2a
dataset[num_vars].describe()
# Out:
#                age     absences           G1           G3
# count  1044.000000  1044.000000  1044.000000  1044.000000
# mean     16.726054     4.434866    11.213602    11.341954
# std       1.239975     6.210017     2.983394     3.864796
# min      15.000000     0.000000     0.000000     0.000000
# 25%      16.000000     0.000000     9.000000    10.000000
# 50%      17.000000     2.000000    11.000000    11.000000
# 75%      18.000000     6.000000    13.000000    14.000000
# max      22.000000    75.000000    19.000000    20.000000

# %%
# Opdracht 3.2b
sns.histplot(dataset, x="age")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(dataset, x="absences")
# Out:
# <Axes: xlabel='absences', ylabel='Count'>

# %%
sns.histplot(dataset, x="G1")
# Out:
# <Axes: xlabel='G1', ylabel='Count'>

# %%
sns.histplot(dataset, x="G3")
# Out:
# <Axes: xlabel='G3', ylabel='Count'>

# %%
# Opdracht 3.2b
sns.boxplot(dataset, x="age")
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(dataset, x="absences")
# Out:
# <Axes: xlabel='absences'>

# %%
sns.boxplot(dataset, x="G1")
# Out:
# <Axes: xlabel='G1'>

# %%
sns.boxplot(dataset, x="G3")
# Out:
# <Axes: xlabel='G3'>

# %%
# Opdracht 4.1a
sns.pairplot(dataset[cat_vars])
# Out:
# C:\Users\User\Nieuwe map\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Opdracht 4.2a
corr_matrix = dataset[num_vars].corr()
corr_matrix
# Out:
#                age  absences        G1        G3
# age       1.000000  0.153196 -0.124121 -0.125282
# absences  0.153196  1.000000 -0.092425 -0.045671
# G1       -0.124121 -0.092425  1.000000  0.809142
# G3       -0.125282 -0.045671  0.809142  1.000000

# %%
# Opdracht 4.2c
sns.pairplot(dataset[num_vars])
# Out:
# C:\Users\User\Nieuwe map\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Opdracht 4.2e
sns.regplot(dataset, x="G1", y="G3")
# Out:
# <Axes: xlabel='G1', ylabel='G3'>

# %%
# Opdracht 4.2f
r2 = dataset["G1"].corr(dataset["G3"])**2
r2_log_vars = dataset["G1"].corr(dataset["G3"])**2
r2, r2_log_vars
# Out:
# (0.6547103239186229, 0.6547103239186229)

# %%
# Opdracht 4.2g
sns.regplot(dataset, x="age", y="absences")
# Out:
# <Axes: xlabel='age', ylabel='absences'>

# %%
r2 = dataset["age"].corr(dataset["absences"])**2
r2_log_vars = dataset["age"].corr(dataset["absences"])**2
r2, r2_log_vars
# Out:
# (0.02346890635572644, 0.02346890635572644)

# %%
# Opdracht 4.2h
sns.regplot(dataset, x="absences", y="G3")
# Out:
# <Axes: xlabel='absences', ylabel='G3'>

# %%
r2 = dataset["absences"].corr(dataset["G3"])**2
r2_log_vars = dataset["absences"].corr(dataset["G3"])**2
r2, r2_log_vars
# Out:
# (0.0020858016024509663, 0.0020858016024509663)
